# %%
import gzip
import numpy as np
from keras.utils import to_categorical
from keras.models import Sequential
from keras.layers import Dense

def open_images(filename):
    with gzip.open(filename, "rb") as file:
        data = file.read()
        return np.frombuffer(data, dtype=np.uint8, offset=16)\
            .reshape(-1, 28, 28)\
            .astype(np.float32)


def open_labels(filename):
    with gzip.open(filename, "rb") as file:
        data = file.read()
        return np.frombuffer(data, dtype=np.uint8, offset=8)

X_train = open_images("data/fashion/train-images-idx3-ubyte.gz")
y_train = open_labels("data/fashion/train-labels-idx1-ubyte.gz")

X_train_mapped = X_train.reshape(60000, 784)
y_train_categorical = to_categorical(y_train)

X_test = open_images("data/fashion/t10k-images-idx3-ubyte.gz").reshape(-1, 784)
y_test = to_categorical(open_labels("data/fashion/t10k-labels-idx1-ubyte.gz"))

# %% [markdown]
# #### Aktivierungsfunktionen durchprobieren

# %%
model = Sequential()
# model.add(Dense(100, activation="relu", input_shape=(784,)))
model.add(Dense(100, activation="tanh", input_shape=(784,)))
# model.add(Dense(100, activation="sigmoid", input_shape=(784,)))

model.add(Dense(10, activation="softmax"))
model.compile(optimizer="sgd", loss="categorical_crossentropy", metrics=["accuracy"])
model.fit(
    X_train_mapped,
    y_train_categorical,
    epochs=10,
    batch_size=1000
)
# Out:
# Epoch 1/10
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.3318 - loss: 2.0357
# Epoch 2/10
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6527 - loss: 1.2489
# Epoch 3/10
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7088 - loss: 1.0481
# Epoch 4/10
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7276 - loss: 0.9487
# Epoch 5/10
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7532 - loss: 0.8689
# Epoch 6/10
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7626 - loss: 0.8150
# Epoch 7/10
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7684 - loss: 0.7776
# Epoch 8/10
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7781 - loss: 0.7443
# Epoch 9/10
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7845 - loss: 0.7168
# Epoch 10/10
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7859 - loss: 0.7002

# %% [markdown]
# #### Epochen erhöhen
#
# - Trainieren, bis sich am "loss" nicht mehr viel ändert.
#
# Hier mit 10 Epochen
#
# <img src="assets/train_10_epochs.png">
#
# Hier mit 100 Epochen
#
# <img src="assets/train_100_epochs.png">

# %% [markdown]
# #### Überprüfen und ggf. mehr Layer hinzufügen
# - Testgenauigkeit nur minimal schlechter als die Trainingsgenauigkeit: Das Modell darf vermutlich noch etwas komplexer sein
# - Testgenauigkeit sehr viel schlechter als die Trainingsgenauigkeit: Das Modell ist zu komplex (das Modell hat sich zu stark an die Trainingsdaten angepasst - z.B. ein Bildrauschen)
# - Beides schlecht: es werden mehr Daten benötigt

# %%
model = Sequential()
# model.add(Dense(100, activation="sigmoid", input_shape=(784,)))
# model.add(Dense(50, activation="sigmoid", input_shape=(784,)))
# man könnte auch folgendes ausprobieren (lediglich trial and error)
model.add(Dense(200, activation="sigmoid", input_shape=(784,)))
model.add(Dense(100, activation="sigmoid", input_shape=(784,)))

model.add(Dense(10, activation="softmax"))
model.compile(optimizer="sgd", loss="categorical_crossentropy", metrics=["accuracy"])
model.fit(
    X_train_mapped,
    y_train_categorical,
    epochs=100,
    batch_size=1000
)

print("Trainingsdaten: ")
print(model.evaluate(X_train_mapped, y_train_categorical))
print("Testdaten: ")
print(model.evaluate(X_test, y_test))
# Out:
# Epoch 1/100
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.1508 - loss: 2.3421
# Epoch 2/100
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.4932 - loss: 2.0344
# Epoch 3/100
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.5912 - loss: 1.8977
# Epoch 4/100
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6153 - loss: 1.7855
# Epoch 5/100
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6362 - loss: 1.6847
# Epoch 6/100
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6586 - loss: 1.5971
# Epoch 7/100
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6722 - loss: 1.5197
# Epoch 8/100
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6875 - loss: 1.4454
# Epoch 9/100
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6976 - loss: 1.3782
# Epoch 10/100
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7034 - loss: 1.3236
# Epoch 11/100
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7127 - loss: 1.2659
# Epoch 12/100
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7147 - loss: 1.2177
# Epoch 13/100
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7258 - loss: 1.1715
# Epoch 14/100
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7279 - loss: 1.1320
# Epoch 15/100
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7334 - loss: 1.0900
# Epoch 16/100
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7372 - loss: 1.0566
# Epoch 17/100
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7420 - loss: 1.0246
# Epoch 18/100
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7412 - loss: 0.9933
# Epoch 19/100
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7481 - loss: 0.9662
# Epoch 20/100
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 2s 25ms/step - accuracy: 0.7481 - loss: 0.9445
# Epoch 21/100
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - accuracy: 0.7553 - loss: 0.9142
# Epoch 22/100
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 2s 25ms/step - accuracy: 0.7563 - loss: 0.8953
# Epoch 23/100
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 2s 24ms/step - accuracy: 0.7596 - loss: 0.8750
# Epoch 24/100
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 2s 24ms/step - accuracy: 0.7624 - loss: 0.8537
# Epoch 25/100
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 2s 26ms/step - accuracy: 0.7659 - loss: 0.8354
# Epoch 26/100
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 2s 24ms/step - accuracy: 0.7692 - loss: 0.8167
# Epoch 27/100
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 2s 26ms/step - accuracy: 0.7720 - loss: 0.8042
# Epoch 28/100
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 2s 27ms/step - accuracy: 0.7705 - loss: 0.7896
# Epoch 29/100
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 2s 24ms/step - accuracy: 0.7779 - loss: 0.7700
# Epoch 30/100
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 2s 25ms/step - accuracy: 0.7817 - loss: 0.7587
# Epoch 31/100
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 2s 26ms/step - accuracy: 0.7854 - loss: 0.7428
# Epoch 32/100
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 2s 25ms/step - accuracy: 0.7881 - loss: 0.7279
# Epoch 33/100
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 2s 26ms/step - accuracy: 0.7887 - loss: 0.7204
# Epoch 34/100
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 0.7914 - loss: 0.7125
# Epoch 35/100
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 0.7938 - loss: 0.6949
# Epoch 36/100
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.7946 - loss: 0.6929
# Epoch 37/100
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.8009 - loss: 0.6738
# Epoch 38/100
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 2s 28ms/step - accuracy: 0.8014 - loss: 0.6679
# Epoch 39/100
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 2s 26ms/step - accuracy: 0.8010 - loss: 0.6634
# Epoch 40/100
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - accuracy: 0.8031 - loss: 0.6528
# Epoch 41/100
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 2s 24ms/step - accuracy: 0.8038 - loss: 0.6453
# Epoch 42/100
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - accuracy: 0.8087 - loss: 0.6366
# Epoch 43/100
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.8079 - loss: 0.6306
# Epoch 44/100
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 2s 24ms/step - accuracy: 0.8100 - loss: 0.6247
# Epoch 45/100
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 2s 26ms/step - accuracy: 0.8111 - loss: 0.6177
# Epoch 46/100
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.8121 - loss: 0.6105
# Epoch 47/100
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 2s 23ms/step - accuracy: 0.8153 - loss: 0.6024
# Epoch 48/100
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - accuracy: 0.8155 - loss: 0.5953
# Epoch 49/100
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - accuracy: 0.8171 - loss: 0.5907
# Epoch 50/100
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - accuracy: 0.8183 - loss: 0.5841
# Epoch 51/100
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - accuracy: 0.8216 - loss: 0.5767
# Epoch 52/100
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 3s 23ms/step - accuracy: 0.8228 - loss: 0.5705
# Epoch 53/100
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 3s 22ms/step - accuracy: 0.8212 - loss: 0.5714
# Epoch 54/100
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 3s 26ms/step - accuracy: 0.8225 - loss: 0.5669
# Epoch 55/100
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 2s 24ms/step - accuracy: 0.8250 - loss: 0.5607
# Epoch 56/100
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 3s 24ms/step - accuracy: 0.8225 - loss: 0.5579
# Epoch 57/100
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 2s 26ms/step - accuracy: 0.8253 - loss: 0.5517
# Epoch 58/100
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - accuracy: 0.8292 - loss: 0.5406
# Epoch 59/100
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 2s 24ms/step - accuracy: 0.8307 - loss: 0.5362
# Epoch 60/100
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 2s 24ms/step - accuracy: 0.8316 - loss: 0.5351
# Epoch 61/100
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 0.8291 - loss: 0.5339
# Epoch 62/100
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 3s 25ms/step - accuracy: 0.8341 - loss: 0.5238
# Epoch 63/100
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - accuracy: 0.8362 - loss: 0.5198
# Epoch 64/100
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - accuracy: 0.8357 - loss: 0.5193
# Epoch 65/100
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 3s 26ms/step - accuracy: 0.8358 - loss: 0.5153
# Epoch 66/100
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 2s 24ms/step - accuracy: 0.8375 - loss: 0.5098
# Epoch 67/100
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 2s 25ms/step - accuracy: 0.8348 - loss: 0.5139
# Epoch 68/100
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 2s 24ms/step - accuracy: 0.8393 - loss: 0.5045
# Epoch 69/100
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 3s 25ms/step - accuracy: 0.8389 - loss: 0.5038
# Epoch 70/100
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - accuracy: 0.8398 - loss: 0.4978
# Epoch 71/100
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - accuracy: 0.8411 - loss: 0.4954
# Epoch 72/100
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 3s 25ms/step - accuracy: 0.8430 - loss: 0.4918
# Epoch 73/100
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 3s 23ms/step - accuracy: 0.8391 - loss: 0.4940
# Epoch 74/100
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 2s 23ms/step - accuracy: 0.8423 - loss: 0.4889
# Epoch 75/100
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 3s 25ms/step - accuracy: 0.8460 - loss: 0.4806
# Epoch 76/100
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - accuracy: 0.8426 - loss: 0.4826
# Epoch 77/100
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - accuracy: 0.8441 - loss: 0.4796
# Epoch 78/100
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 3s 24ms/step - accuracy: 0.8427 - loss: 0.4781
# Epoch 79/100
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 2s 24ms/step - accuracy: 0.8426 - loss: 0.4776
# Epoch 80/100
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - accuracy: 0.8460 - loss: 0.4749
# Epoch 81/100
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 3s 23ms/step - accuracy: 0.8441 - loss: 0.4743
# Epoch 82/100
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - accuracy: 0.8444 - loss: 0.4730
# Epoch 83/100
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 2s 24ms/step - accuracy: 0.8472 - loss: 0.4654
# Epoch 84/100
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 2s 24ms/step - accuracy: 0.8481 - loss: 0.4637
# Epoch 85/100
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 3s 25ms/step - accuracy: 0.8484 - loss: 0.4596
# Epoch 86/100
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 2s 23ms/step - accuracy: 0.8469 - loss: 0.4627
# Epoch 87/100
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - accuracy: 0.8491 - loss: 0.4601
# Epoch 88/100
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - accuracy: 0.8502 - loss: 0.4538
# Epoch 89/100
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 3s 24ms/step - accuracy: 0.8519 - loss: 0.4525
# Epoch 90/100
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - accuracy: 0.8536 - loss: 0.4465
# Epoch 91/100
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 2s 25ms/step - accuracy: 0.8516 - loss: 0.4527
# Epoch 92/100
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 3s 24ms/step - accuracy: 0.8521 - loss: 0.4478
# Epoch 93/100
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 2s 25ms/step - accuracy: 0.8518 - loss: 0.4458
# Epoch 94/100
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 3s 26ms/step - accuracy: 0.8564 - loss: 0.4363
# Epoch 95/100
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 3s 26ms/step - accuracy: 0.8549 - loss: 0.4368
# Epoch 96/100
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 2s 24ms/step - accuracy: 0.8549 - loss: 0.4396
# Epoch 97/100
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 3s 23ms/step - accuracy: 0.8545 - loss: 0.4378
# Epoch 98/100
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 2s 26ms/step - accuracy: 0.8538 - loss: 0.4383
# Epoch 99/100
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 3s 26ms/step - accuracy: 0.8558 - loss: 0.4310
# Epoch 100/100
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - accuracy: 0.8552 - loss: 0.4380
# Trainingsdaten:
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 10s 5ms/step - accuracy: 0.8564 - loss: 0.4309
# [0.43250226974487305, 0.8550833463668823]
# Testdaten:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.8336 - loss: 0.4851
# [0.4897848665714264, 0.8306999802589417]
