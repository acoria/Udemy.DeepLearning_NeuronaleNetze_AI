# %%
import pandas as pd

#df: dataframe (Konvention, es mit df zu bezeichnen)
df = pd.read_csv("data/mpg-dataset.csv")

# pandas kann auch andere Formate, wie z.B. read_excel()

# %%
df
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0    18.0          8         307.0         130    3504          12.0
# 1    15.0          8         350.0         165    3693          11.5
# 2    18.0          8         318.0         150    3436          11.0
# 3    16.0          8         304.0         150    3433          12.0
# 4    17.0          8         302.0         140    3449          10.5
# ..    ...        ...           ...         ...     ...           ...
# 387  27.0          4         140.0          86    2790          15.6
# 388  44.0          4          97.0          52    2130          24.6
# 389  32.0          4         135.0          84    2295          11.6
# 390  28.0          4         120.0          79    2625          18.6
# 391  31.0          4         119.0          82    2720          19.4
#
#      model_year  origin                       name
# 0            70       1  chevrolet chevelle malibu
# ...

# %%
# Spalten aus dem Dataframe auslesen
columns = df[["cylinders", "horsepower", "weight"]]

# %%
columns
# Out:
#      cylinders  horsepower  weight
# 0            8         130    3504
# 1            8         165    3693
# 2            8         150    3436
# 3            8         150    3433
# 4            8         140    3449
# ..         ...         ...     ...
# 387          4          86    2790
# 388          4          52    2130
# 389          4          84    2295
# 390          4          79    2625
# 391          4          82    2720
#
# [392 rows x 3 columns]
